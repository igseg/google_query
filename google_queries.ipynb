# %% [markdown]
# <a href="https://colab.research.google.com/github/igseg/google_query/blob/master/google_queries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pygooglenews
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pygooglenews
#   Downloading pygooglenews-0.1.2-py3-none-any.whl (10 kB)
# Collecting beautifulsoup4<5.0.0,>=4.9.1
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 4.7 MB/s
# Collecting requests<3.0.0,>=2.24.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.5 MB/s
# Collecting dateparser<0.8.0,>=0.7.6
#   Downloading dateparser-0.7.6-py2.py3-none-any.whl (362 kB)
#      |████████████████████████████████| 362 kB 32.3 MB/s
# Collecting feedparser<6.0.0,>=5.2.1
#   Downloading feedparser-5.2.1.zip (1.2 MB)
#      |████████████████████████████████| 1.2 MB 52.0 MB/s
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2.8.2)
# Requirement already satisfied: regex!=2019.02.19 in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.6.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (1.5.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->dateparser<0.8.0,>=0.7.6->pygooglenews) (1.15.0)
# Building wheels for collected packages: feedparser
#   Building wheel for feedparser (setup.py) ... done
#   Created wheel for feedparser: filename=feedparser-5.2.1-py3-none-any.whl size=44952 sha256=685b73ed4efa3c95bcb9b62cb6a2040d995f0ac10666e5582783c679a1ef8b1f
#   Stored in directory: /root/.cache/pip/wheels/29/bf/46/b4a597d435d3aee6c2fa583824897336d65abf13ebe3405b70
# Successfully built feedparser
# Installing collected packages: soupsieve, requests, feedparser, dateparser, beautifulsoup4, pygooglenews
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.11.1 dateparser-0.7.6 feedparser-5.2.1 pygooglenews-0.1.2 requests-2.28.1 soupsieve-2.3.2.post1

# %%
from pygooglenews import GoogleNews
import unicodedata
import re

# %%
def search(query, language = 'es', country = 'ES', date = '7d'):
  '''
  query is the search we are making.

  language is the browser's language ('en' for English)

  country is the browser's country ('US' for United States)

  date limits how old the entry may be. '7d' for, at most, 1 week old entries.
  '''

  # Notes for myself: Add parameter for max_searchs (rn it's 100)

  gn = GoogleNews(lang = language, country = country)

  s = gn.search(f" '{query}' when:{date} ")

  search_entries = s['entries']
  search_results = []

  for entry in search_entries:
    ''' entry keys are: 'title', 'title_detail', 'links', 'link', 'id', 'guidislink'
     , 'published', 'published_parsed', 'summary', 'summary_detail', 'source', 'sub_articles'

     We are interested in: title, link, summary
    '''
    objective = {
        'title'   : entry.title,
        'link'    : entry.link,
        'summary' : entry.summary,
        'score'   : 0
    }
    search_results.append(objective)

  return search_results

def remove_accents(input_str):
    nfkd_form  = unicodedata.normalize('NFKD', input_str)
    only_ascii = nfkd_form.encode('ASCII', 'ignore')
    return only_ascii

def string_treatment(string):
  # String cleaning
  res_without_accents = remove_accents(string)                                           # remove accent marks
  res_clean           = re.sub(r'\W+', ' ', res_without_accents.decode("utf-8")).lower() # remove non alphanumerical characters and lower everything
  res_clean_list      = res_clean.split(' ')                                             # split string by blanks

  return res_clean_list

def computeTF(wordDict, bagOfWords):
    tfDict = {}
    bagOfWordsCount = len(bagOfWords)
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
    return tfDict

def computeIDF(documents):
  import math
  N = len(documents)
  
  idfDict = dict.fromkeys(documents[0].keys(), 0)
  for document in documents:
      for word, val in document.items():
          if val > 0:
              idfDict[word] += 1
  
  for word, val in idfDict.items():
      idfDict[word] = math.log(N / float(val))
  return idfDict

def computeTFIDF(tfBagOfWords, idfs):
  tfidf = {}
  for word, val in tfBagOfWords.items():
      tfidf[word] = val * idfs[word]
  return tfidf

def scoring_function(keywords, tf_idf):
  '''
  Calculate the score of the keywords tf_idf
  '''
  score = 0
  for keyword in keywords:
    try: 
      score += tf_idf[keyword]
    except KeyError: 
      pass
    
  return score

def calibrate_scores_tfidf(results,keywords):
  '''
  Calcualte tfidf for each word in each document, then sum the scores of the
  keywords in order to produce the final score
  '''
  bag_of_words = []
  for i in range(len(results)):
    bag_of_words.append(string_treatment(results[i]['summary']))

  unique_words = set(bag_of_words[0])

  for i in range(len(results)):
    if i == 0:
      continue

    unique_words = unique_words.union(bag_of_words[i])

  num_of_words = []

  for i in range(len(results)):
    num_of_words.append(dict.fromkeys(unique_words, 0))
    for word in bag_of_words[i]:
      num_of_words[i][word] += 1

  tf = []

  for i in range(len(results)):
    tf.append(computeTF(num_of_words[i], bag_of_words[i]))

  idfs = computeIDF(num_of_words)

  tfidf = []

  for i in range(len(results)):
    tfidf.append(computeTFIDF(tf[i], idfs))

  for i in range(len(results)):
    results[i]['score'] = scoring_function(keywords, tfidf[i])

  return results

# %%
keywords = ['hidrogeno', 'verde', 'planta', 'proyecto'] # This list has to be expanded trought expert criteria
                                                        # IMPORTANT: keywords in lowercase WITHOUT special characters

results  = search('hidrogeno verde')                    # Example for just one query, implement loop for multiple searches

scored_results = calibrate_scores_tfidf(results, keywords)
sorted_results = sorted(scored_results, key=lambda item: -item['score'])

# %%
sorted_results
# Out:
# [{'title': 'Haro presenta al programa Misiones Ciencia e Innovacion su proyecto para crear una planta de hidrógeno verde - Haro Digital',
#   'link': 'https://harodigital.com/medioambiente/haro-presenta-al-programa-misiones-ciencia-e-innovacion-su-proyecto-para-crear-una-planta-de-hidrogeno-verde/',
#   'summary': '<a href="https://harodigital.com/medioambiente/haro-presenta-al-programa-misiones-ciencia-e-innovacion-su-proyecto-para-crear-una-planta-de-hidrogeno-verde/" target="_blank">Haro presenta al programa Misiones Ciencia e Innovacion su proyecto para crear una planta de hidrógeno verde</a>&nbsp;&nbsp;<font color="#6f6f6f">Haro Digital</font>',
#   'score': 0.2506119054097133},
#  {'title': 'La Junta proyecta una planta de hidrógeno verde en Los Barrios (Cádiz) - El Periodico de la Energía',
#   'link': 'https://elperiodicodelaenergia.com/junta-proyecta-planta-hidrogeno-verde-barrios-cadiz/',
#   'summary': '<a href="https://elperiodicodelaenergia.com/junta-proyecta-planta-hidrogeno-verde-barrios-cadiz/" target="_blank">La Junta proyecta una planta de hidrógeno verde en Los Barrios (Cádiz)</a>&nbsp;&nbsp;<font color="#6f6f6f">El Periodico de la Energía</font>',
#   'score': 0.22219954580105916},
#  {'title': '¿CÓMO SERÁ EL DESARROLLO DE SIERRA GRANDE A PARTIR DE LA PLANTA DE HIDRÓGENO VERDE? (AUDIO) - LU17.COM',
#   'link': 'https://lu17.com/whatsapp/como-sera-el-desarrollo-de-sierra-grande-a-partir-de-la-planta-de-hidrogeno-verde-audio',
#   'summary': '<a href="https://lu17.com/whatsapp/como-sera-el-desarrollo-de-sierra-grande-a-partir-de-la-planta-de-hidrogeno-verde-audio" target="_blank">¿CÓMO SERÁ EL DESARROLLO DE SIERRA GRANDE A PARTIR DE LA PLANTA DE HIDRÓGENO VERDE? (AUDIO)</a>&nbsp;&nbsp;<font color="#6f6f6f">LU17.COM</font>',
#   'score': 0.17427415356945813},
#  {'title': 'La Ciuden contará con un proyecto de hidrógeno verde de 30 millones - El Periodico de la Energía',
#   'link': 'https://elperiodicodelaenergia.com/ciuden-contara-proyecto-hidrogeno-verde-30-millones/',
#   'summary': '<a href="https://elperiodicodelaenergia.com/ciuden-contara-proyecto-hidrogeno-verde-30-millones/" target="_blank">La Ciuden contará con un proyecto de hidrógeno verde de 30 millones</a>&nbsp;&nbsp;<font color="#6f6f6f">El Periodico de la Energía</font>',
#   'score': 0.1572353965945461},
#  {'title': 'Continúan las reacciones magallánicas ante retiro de proyecto de hidrógeno verde - El Pingüino',
#   'link': 'https://elpinguino.com/noticia/2022/10/10/continuan-las-reacciones-magallanicas-ante-retiro-de-proyecto-de-hidrogeno-verde',
#   'summary': '<a href="https://elpinguino.com/noticia/2022/10/10/continuan-las-reacciones-magallanicas-ante-retiro-de-proyecto-de-hidrogeno-verde" target="_blank">Continúan las reacciones magallánicas ante retiro de proyecto de hidrógeno verde</a>&nbsp;&nbsp;<font color="#6f6f6f">El Pingüino</font>',
#   'score': 0.14294126963140558},
#  {'title': 'Tvitec utilizará sólo hidrógeno verde en un proyecto de 180 M€ y 250 empleos - Diario de León',
#   'link': 'https://www.diariodeleon.es/articulo/bierzo/tvitec-utilizara-solo-hidrogeno-verde-proyecto-180-mE-250-empleos/202210070333432264809.html',
#   'summary': '<a href="https://www.diariodeleon.es/articulo/bierzo/tvitec-utilizara-solo-hidrogeno-verde-proyecto-180-mE-250-empleos/202210070333432264809.html" target="_blank">Tvitec utilizará sólo hidrógeno verde en un proyecto de 180 M€ y 250 empleos</a>&nbsp;&nbsp;<font color="#6f6f6f">Diario de León</font>',
#   'score': 0.13102949716212176},
#  {'title': 'TES y Fortescue quieren desarrollar el mayor proyecto de hidrógeno verde del mundo - World Energy Trade - worldenergytrade',
#   'link': 'https://www.worldenergytrade.com/energias-alternativas/gas/tes-y-fortescue-quieren-desarrollar-el-mayor-proyecto-de-hidrogeno-verde-del-mundo',
#   'summary': '<a href="https://www.worldenergytrade.com/energias-alternativas/gas/tes-y-fortescue-quieren-desarrollar-el-mayor-proyecto-de-hidrogeno-verde-del-mundo" target="_blank">TES y Fortescue quieren desarrollar el mayor proyecto de hidrógeno verde del mundo - World Energy Trade</a>&nbsp;&nbsp;<font color="#6f6f6f">worldenergytrade</font>',
#   'score': 0.12578831727563689},
#  {'title': 'Engie apunta a tener listo en 2023 su proyecto de hidrógeno verde en Ilo - El Comercio Perú',
#   'link': 'https://elcomercio.pe/economia/dia-1/engie-apunta-a-tener-listo-en-2023-su-proyecto-de-hidrogeno-verde-en-ilo-noticia/',
#   'summary': '<a href="https://elcomercio.pe/economia/dia-1/engie-apunta-a-tener-listo-en-2023-su-proyecto-de-hidrogeno-verde-en-ilo-noticia/" target="_blank">Engie apunta a tener listo en 2023 su proyecto de hidrógeno verde en Ilo</a>&nbsp;&nbsp;<font color="#6f6f6f">El Comercio Perú</font>',
#   'score': 0.12332187968199695},
#  {'title': 'Montero reduce casi 10 veces la partida para el proyecto país de hidrógeno verde - lainformacion.com',
#   'link': 'https://www.lainformacion.com/economia-negocios-y-finanzas/montero-reduce-casi-10-veces-la-partida-para-el-proyecto-pais-de-hidrogeno-verde/2874723/',
#   'summary': '<a href="https://www.lainformacion.com/economia-negocios-y-finanzas/montero-reduce-casi-10-veces-la-partida-para-el-proyecto-pais-de-hidrogeno-verde/2874723/" target="_blank">Montero reduce casi 10 veces la partida para el proyecto país de hidrógeno verde</a>&nbsp;&nbsp;<font color="#6f6f6f">lainformacion.com</font>',
#   'score': 0.12095030507272778},
#  {'title': 'Papá de Boric cuestiona exigencias de Seremi a retirado proyecto de hidrógeno verde en Magallanes - BioBioChile',
#   'link': 'https://www.biobiochile.cl/noticias/nacional/chile/2022/10/07/papa-de-boric-cuestiona-exigencias-de-seremi-a-retirado-proyecto-de-hidrogeno-verde-en-magallanes.shtml',
#   'summary': '<a href="https://www.biobiochile.cl/noticias/nacional/chile/2022/10/07/papa-de-boric-cuestiona-exigencias-de-seremi-a-retirado-proyecto-de-hidrogeno-verde-en-magallanes.shtml" target="_blank">Papá de Boric cuestiona exigencias de Seremi a retirado proyecto de hidrógeno verde en Magallanes</a>&nbsp;&nbsp;<font color="#6f6f6f">BioBioChile</font>',
#   'score': 0.11435301570512443},
#  {'title': 'Nortegas culmina "con éxito" la primera fase de su proyecto H2Sarea - El Periodico de la Energía',
#   'link': 'https://elperiodicodelaenergia.com/nortegas-culmina-exito-primera-fase-proyecto-h2sarea/',
#   'summary': '<a href="https://elperiodicodelaenergia.com/nortegas-culmina-exito-primera-fase-proyecto-h2sarea/" target="_blank">Nortegas culmina "con éxito" la primera fase de su proyecto H2Sarea</a>&nbsp;&nbsp;<font color="#6f6f6f">El Periodico de la Energía</font>',
#   'score': 0.11267818345313946},
#  {'title': 'INCERTEZA JURIDICA AMBIENTAL GENERA RETIRO DEL PRINCIPAL PROYECTO DE HIDROGENO VERDE DE MAGALLANES - radiopolar.com',
#   'link': 'https://www.radiopolar.com/noticia_180105.html',
#   'summary': '<a href="https://www.radiopolar.com/noticia_180105.html" target="_blank">INCERTEZA JURIDICA AMBIENTAL GENERA RETIRO DEL PRINCIPAL PROYECTO DE HIDROGENO VERDE DE MAGALLANES</a>&nbsp;&nbsp;<font color="#6f6f6f">radiopolar.com</font>',
#   'score': 0.09249140976149771},
#  {'title': 'Fusion Fuel vende por 2 millones de euros tecnología a Keme Energy para un proyecto de hidrógeno verde de 1,22 MW en Portugal - pv magazine España',
#   'link': 'https://www.pv-magazine.es/2022/10/07/fusion-fuel-vende-por-2-millones-de-euros-tecnologia-a-keme-energy-para-un-proyecto-de-hidrogeno-verde-de-122-mw-en-portugal/',
#   'summary': '<a href="https://www.pv-magazine.es/2022/10/07/fusion-fuel-vende-por-2-millones-de-euros-tecnologia-a-keme-energy-para-un-proyecto-de-hidrogeno-verde-de-122-mw-en-portugal/" target="_blank">Fusion Fuel vende por 2 millones de euros tecnología a Keme Energy para un proyecto de hidrógeno verde de 1,22 MW en Portugal</a>&nbsp;&nbsp;<font color="#6f6f6f">pv magazine España</font>',
#   'score': 0.0885833220250964},
#  {'title': 'Alcalde Pumarejo habla sobre producción de hidrogeno verde, azul y amoniaco verde - EL HERALDO',
#   'link': 'https://www.elheraldo.co/barranquilla/alcalde-pumarejo-habla-sobre-produccion-de-hidrogeno-verde-azul-y-amoniaco-verde-944235',
#   'summary': '<a href="https://www.elheraldo.co/barranquilla/alcalde-pumarejo-habla-sobre-produccion-de-hidrogeno-verde-azul-y-amoniaco-verde-944235" target="_blank">Alcalde Pumarejo habla sobre producción de hidrogeno verde, azul y amoniaco verde</a>&nbsp;&nbsp;<font color="#6f6f6f">EL HERALDO</font>',
#   'score': 0.07247023107827318},
#  {'title': 'El gaseoso sueño del hidrógeno verde - Cambio Colombia',
#   'link': 'https://cambiocolombia.com/articulo/tecnologia/el-gaseoso-sueno-del-hidrogeno-verde',
#   'summary': '<a href="https://cambiocolombia.com/articulo/tecnologia/el-gaseoso-sueno-del-hidrogeno-verde" target="_blank">El gaseoso sueño del hidrógeno verde</a>&nbsp;&nbsp;<font color="#6f6f6f">Cambio Colombia</font>',
#   'score': 0.05921770965966891},
#  {'title': '¿Qué es el hidrógeno verde y cómo se produce? | Eltiempo.es - Eltiempo.es',
#   'link': 'https://www.eltiempo.es/noticias/hidrogeno-verde',
#   'summary': '<a href="https://www.eltiempo.es/noticias/hidrogeno-verde" target="_blank">¿Qué es el hidrógeno verde y cómo se produce? | Eltiempo.es</a>&nbsp;&nbsp;<font color="#6f6f6f">Eltiempo.es</font>',
#   'score': 0.057423233609375915},
#  {'title': 'No lo llame hidrógeno verde, llámelo gas fósil - El Salto',
#   'link': 'https://www.elsaltodiario.com/crisis-energetica/hidrogeno-verde-llamelo-gas-fosil',
#   'summary': '<a href="https://www.elsaltodiario.com/crisis-energetica/hidrogeno-verde-llamelo-gas-fosil" target="_blank">No lo llame hidrógeno verde, llámelo gas fósil</a>&nbsp;&nbsp;<font color="#6f6f6f">El Salto</font>',
#   'score': 0.055734314973806036},
#  {'title': 'Río Negro continúa concientizando sobre el hidrógeno verde - LM Neuquen',
#   'link': 'https://mase.lmneuquen.com/rio-negro/rio-negro-continua-concientizando-el-hidrogeno-verde-n954510',
#   'summary': '<a href="https://mase.lmneuquen.com/rio-negro/rio-negro-continua-concientizando-el-hidrogeno-verde-n954510" target="_blank">Río Negro continúa concientizando sobre el hidrógeno verde</a>&nbsp;&nbsp;<font color="#6f6f6f">LM Neuquen</font>',
#   'score': 0.05121531646241636},
#  {'title': 'Ingenieros fabrican hidrógeno verde a partir del aire - World Energy Trade - worldenergytrade',
#   'link': 'https://www.worldenergytrade.com/energias-alternativas/gas/ingenieros-hidrogeno-verde-a-partir-del-aire',
#   'summary': '<a href="https://www.worldenergytrade.com/energias-alternativas/gas/ingenieros-hidrogeno-verde-a-partir-del-aire" target="_blank">Ingenieros fabrican hidrógeno verde a partir del aire - World Energy Trade</a>&nbsp;&nbsp;<font color="#6f6f6f">worldenergytrade</font>',
#   'score': 0.048588889977164235},
#  {'title': 'Instan a regular uso de hidrógeno verde - El Sol de México',
#   'link': 'https://www.elsoldemexico.com.mx/finanzas/instan-a-regular-uso-de-hidrogeno-verde-9012247.html',
#   'summary': '<a href="https://www.elsoldemexico.com.mx/finanzas/instan-a-regular-uso-de-hidrogeno-verde-9012247.html" target="_blank">Instan a regular uso de hidrógeno verde</a>&nbsp;&nbsp;<font color="#6f6f6f">El Sol de México</font>',
#   'score': 0.048588889977164235},
#  {'title': 'BP Castellón quiere vender hidrógeno verde a Alemania en 2030 - Economía Digital Comunidad Valenciana',
#   'link': 'https://www.economiadigital.es/valencia/empresas/bp-castellon-hidrogeno-verde-alemania.html',
#   'summary': '<a href="https://www.economiadigital.es/valencia/empresas/bp-castellon-hidrogeno-verde-alemania.html" target="_blank">BP Castellón quiere vender hidrógeno verde a Alemania en 2030</a>&nbsp;&nbsp;<font color="#6f6f6f">Economía Digital Comunidad Valenciana</font>',
#   'score': 0.048588889977164235},
#  {'title': 'Segunda Escuela de Hidrógeno Verde: educando para una transición energética sostenible - Usach',
#   'link': 'https://www.usach.cl/news/segunda-escuela-hidrogeno-verde-educando-para-transicion-energetica-sostenible',
#   'summary': '<a href="https://www.usach.cl/news/segunda-escuela-hidrogeno-verde-educando-para-transicion-energetica-sostenible" target="_blank">Segunda Escuela de Hidrógeno Verde: educando para una transición energética sostenible</a>&nbsp;&nbsp;<font color="#6f6f6f">Usach</font>',
#   'score': 0.048588889977164235},
#  {'title': 'Dudas sobre la explosión de hidrógeno verde en Chile - IPS Agencia de Noticias',
#   'link': 'https://ipsnoticias.net/2022/10/dudas-sobre-la-explosion-de-hidrogeno-verde-en-chile/',
#   'summary': '<a href="https://ipsnoticias.net/2022/10/dudas-sobre-la-explosion-de-hidrogeno-verde-en-chile/" target="_blank">Dudas sobre la explosión de hidrógeno verde en Chile</a>&nbsp;&nbsp;<font color="#6f6f6f">IPS Agencia de Noticias</font>',
#   'score': 0.04737416772773513},
#  {'title': 'Hidrógeno, un Futuro “Verde” para la Gran Industria - El Economista',
#   'link': 'https://www.eleconomista.com.mx/opinion/Hidrogeno-un-Futuro-Verde-para-la-Gran-Industria-20221007-0004.html',
#   'summary': '<a href="https://www.eleconomista.com.mx/opinion/Hidrogeno-un-Futuro-Verde-para-la-Gran-Industria-20221007-0004.html" target="_blank">Hidrógeno, un Futuro “Verde” para la Gran Industria</a>&nbsp;&nbsp;<font color="#6f6f6f">El Economista</font>',
#   'score': 0.04737416772773513},
#  {'title': 'El hidrógeno verde se postula como solución para la transición energética - ABC.es',
#   'link': 'https://www.abc.es/motor/motoreco/hidrogeno-verde-postula-solucion-transicion-energetica-20221006162336-nt.html',
#   'summary': '<a href="https://www.abc.es/motor/motoreco/hidrogeno-verde-postula-solucion-transicion-energetica-20221006162336-nt.html" target="_blank">El hidrógeno verde se postula como solución para la transición energética</a>&nbsp;&nbsp;<font color="#6f6f6f">ABC.es</font>',
#   'score': 0.046218700222180616},
#  {'title': 'Reclaman regular el negocio del hidrógeno verde mediante una ley - iProfesional.com',
#   'link': 'https://www.iprofesional.com/economia/370859-reclaman-regular-el-negocio-del-hidrogeno-verde-mediante-una-ley',
#   'summary': '<a href="https://www.iprofesional.com/economia/370859-reclaman-regular-el-negocio-del-hidrogeno-verde-mediante-una-ley" target="_blank">Reclaman regular el negocio del hidrógeno verde mediante una ley</a>&nbsp;&nbsp;<font color="#6f6f6f">iProfesional.com</font>',
#   'score': 0.046218700222180616},
#  {'title': 'La cooperación, aspecto clave para el potencial de la Comunitat en hidrógeno verde - Valencia Plaza',
#   'link': 'https://valenciaplaza.com/la-cooperacion-aspecto-clave-para-el-potencial-comunitat-en-hidrogeno-verde',
#   'summary': '<a href="https://valenciaplaza.com/la-cooperacion-aspecto-clave-para-el-potencial-comunitat-en-hidrogeno-verde" target="_blank">La cooperación, aspecto clave para el potencial de la Comunitat en hidrógeno verde</a>&nbsp;&nbsp;<font color="#6f6f6f">Valencia Plaza</font>',
#   'score': 0.04511825497879536},
#  {'title': 'Uruguay planea licitaciones de energía eólica e hidrógeno verde para 2023 - BNamericas',
#   'link': 'https://www.bnamericas.com/es/noticias/uruguay-planea-licitaciones-de-energia-eolica-e-hidrogeno-verde-para-2023',
#   'summary': '<a href="https://www.bnamericas.com/es/noticias/uruguay-planea-licitaciones-de-energia-eolica-e-hidrogeno-verde-para-2023" target="_blank">Uruguay planea licitaciones de energía eólica e hidrógeno verde para 2023</a>&nbsp;&nbsp;<font color="#6f6f6f">BNamericas</font>',
#   'score': 0.04511825497879536},
#  {'title': 'Corea del Sur interesada en acuerdos con Uruguay por Hidrógeno Verde - Surtidores.com.ar',
#   'link': 'https://surtidores.com.ar/corea-del-sur-interesada-en-acuerdos-con-uruguay-por-hidrogeno-verde/',
#   'summary': '<a href="https://surtidores.com.ar/corea-del-sur-interesada-en-acuerdos-con-uruguay-por-hidrogeno-verde/" target="_blank">Corea del Sur interesada en acuerdos con Uruguay por Hidrógeno Verde</a>&nbsp;&nbsp;<font color="#6f6f6f">Surtidores.com.ar</font>',
#   'score': 0.04511825497879536},
#  {'title': 'Viceministra de Energía visitó en Cartagena Laboratorio de Hidrógeno Verde - Caracol Radio',
#   'link': 'https://caracol.com.co/2022/10/08/viceministra-de-energia-visito-en-cartagena-laboratorio-de-hidrogeno-verde/',
#   'summary': '<a href="https://caracol.com.co/2022/10/08/viceministra-de-energia-visito-en-cartagena-laboratorio-de-hidrogeno-verde/" target="_blank">Viceministra de Energía visitó en Cartagena Laboratorio de Hidrógeno Verde</a>&nbsp;&nbsp;<font color="#6f6f6f">Caracol Radio</font>',
#   'score': 0.04511825497879536},
#  {'title': 'Hidrógeno Verde: Fortescue inició la evaluación ambiental en Punta Colorada - Diario Río Negro',
#   'link': 'https://www.rionegro.com.ar/politica/hidrogeno-verde-fortescue-inicio-la-evaluacion-ambiental-en-punta-colorada-2535379/',
#   'summary': '<a href="https://www.rionegro.com.ar/politica/hidrogeno-verde-fortescue-inicio-la-evaluacion-ambiental-en-punta-colorada-2535379/" target="_blank">Hidrógeno Verde: Fortescue inició la evaluación ambiental en Punta Colorada</a>&nbsp;&nbsp;<font color="#6f6f6f">Diario Río Negro</font>',
#   'score': 0.044068993235102445},
#  {'title': 'Uruguay atrae a empresas globales que apuestan por el hidrógeno verde - El Observador',
#   'link': 'https://www.elobservador.com.uy/nota/uruguay-atrae-a-empresas-globales-que-apuestan-por-el-hidrogeno-verde-20221095047',
#   'summary': '<a href="https://www.elobservador.com.uy/nota/uruguay-atrae-a-empresas-globales-que-apuestan-por-el-hidrogeno-verde-20221095047" target="_blank">Uruguay atrae a empresas globales que apuestan por el hidrógeno verde</a>&nbsp;&nbsp;<font color="#6f6f6f">El Observador</font>',
#   'score': 0.04306742520703194},
#  {'title': 'Los colores del hidrógeno: España apuesta por el verde, otros países de la UE lo hacen por el azul - 20minutos.es',
#   'link': 'https://www.20minutos.es/noticia/5063793/0/colores-hidrogeno-verde-azul-gris/',
#   'summary': '<a href="https://www.20minutos.es/noticia/5063793/0/colores-hidrogeno-verde-azul-gris/" target="_blank">Los colores del hidrógeno: España apuesta por el verde, otros países de la UE lo hacen por el azul</a>&nbsp;&nbsp;<font color="#6f6f6f">20minutos.es</font>',
#   'score': 0.04119492845890012},
#  {'title': "'Project Manager' de Renovables y Responsable de Desarrollo de Hidrógeno verde, perfiles mejor pagados en energía - El Periodico de la Energía",
#   'link': 'https://elperiodicodelaenergia.com/project-manager-renovables-responsable-desarrollo-hidrogeno-verde-perfiles-energia/',
#   'summary': '<a href="https://elperiodicodelaenergia.com/project-manager-renovables-responsable-desarrollo-hidrogeno-verde-perfiles-energia/" target="_blank">\'Project Manager\' de Renovables y Responsable de Desarrollo de Hidrógeno verde, perfiles mejor pagados en energía</a>&nbsp;&nbsp;<font color="#6f6f6f">El Periodico de la Energía</font>',
#   'score': 0.04119492845890012},
#  {'title': 'Así será el mapa (y la red) del hidrógeno verde en Galicia - Economía Digital Galicia',
#   'link': 'https://www.economiadigital.es/galicia/empresas/asi-sera-el-mapa-y-la-red-del-hidrogeno-verde-en-galicia.html',
#   'summary': '<a href="https://www.economiadigital.es/galicia/empresas/asi-sera-el-mapa-y-la-red-del-hidrogeno-verde-en-galicia.html" target="_blank">Así será el mapa (y la red) del hidrógeno verde en Galicia</a>&nbsp;&nbsp;<font color="#6f6f6f">Economía Digital Galicia</font>',
#   'score': 0.04031844061934905},
#  {'title': 'Javier Sancho (Repsol): "El hidrógeno verde transformará el polo petroquímico de Tarragona" - elEconomista',
#   'link': 'https://www.eleconomista.es/energia/noticias/11981644/10/22/Javier-Sancho-Repsol-El-hidrogeno-verde-transformara-el-polo-petroquimico-de-Tarragona.html',
#   'summary': '<a href="https://www.eleconomista.es/energia/noticias/11981644/10/22/Javier-Sancho-Repsol-El-hidrogeno-verde-transformara-el-polo-petroquimico-de-Tarragona.html" target="_blank">Javier Sancho (Repsol): "El hidrógeno verde transformará el polo petroquímico de Tarragona"</a>&nbsp;&nbsp;<font color="#6f6f6f">elEconomista</font>',
#   'score': 0.039478473106445935},
#  {'title': 'El parking de Astilleros se convertirá en un parque solar para producir hidrógeno verde - Viva Sevilla',
#   'link': 'https://vivasevilla.es/sevilla/1087091/el-parking-de-astilleros-se-convertira-en-un-parque-solar-para-producir-hidrogeno-verde/',
#   'summary': '<a href="https://vivasevilla.es/sevilla/1087091/el-parking-de-astilleros-se-convertira-en-un-parque-solar-para-producir-hidrogeno-verde/" target="_blank">El parking de Astilleros se convertirá en un parque solar para producir hidrógeno verde</a>&nbsp;&nbsp;<font color="#6f6f6f">Viva Sevilla</font>',
#   'score': 0.039478473106445935},
#  {'title': 'Firmas españolas y niponas buscan ampliar cooperación en el hidrógeno verde Por EFE - Investing.com España',
#   'link': 'https://es.investing.com/news/commodities-news/firmas-espanolas-y-niponas-buscan-ampliar-cooperacion-en-el-hidrogeno-verde-2302059',
#   'summary': '<a href="https://es.investing.com/news/commodities-news/firmas-espanolas-y-niponas-buscan-ampliar-cooperacion-en-el-hidrogeno-verde-2302059" target="_blank">Firmas españolas y niponas buscan ampliar cooperación en el hidrógeno verde Por EFE</a>&nbsp;&nbsp;<font color="#6f6f6f">Investing.com España</font>',
#   'score': 0.039478473106445935},
#  {'title': 'El Plan Estratégico de Hidrógeno Verde de Río Negro se presentó en Roma - VDM Noticias',
#   'link': 'https://www.vdmnoticias.com/noticias/leer/el-plan-estrategico-de-hidrogeno-verde-de-rio-negro-se-presento-en-roma/13474',
#   'summary': '<a href="https://www.vdmnoticias.com/noticias/leer/el-plan-estrategico-de-hidrogeno-verde-de-rio-negro-se-presento-en-roma/13474" target="_blank">El Plan Estratégico de Hidrógeno Verde de Río Negro se presentó en Roma</a>&nbsp;&nbsp;<font color="#6f6f6f">VDM Noticias</font>',
#   'score': 0.039478473106445935},
#  {'title': 'Cepsa pide priorizar hidrógeno verde para aumentar autonomía energética en UE Por EFE - Investing.com España',
#   'link': 'https://es.investing.com/news/commodities-news/cepsa-pide-priorizar-hidrogeno-verde-para-aumentar-autonomia-energetica-en-ue-2302031',
#   'summary': '<a href="https://es.investing.com/news/commodities-news/cepsa-pide-priorizar-hidrogeno-verde-para-aumentar-autonomia-energetica-en-ue-2302031" target="_blank">Cepsa pide priorizar hidrógeno verde para aumentar autonomía energética en UE Por EFE</a>&nbsp;&nbsp;<font color="#6f6f6f">Investing.com España</font>',
#   'score': 0.039478473106445935},
#  {'title': 'Gustavo Menna: «Debemos darle un marco legal a la producción de hidrógeno verde» – Noticias y Protagonistas - Noticias y Protagonistas',
#   'link': 'https://noticiasyprotagonistas.com/actualidad/gustavo-menna-debemos-darle-un-marco-legal-a-la-produccion-de-hidrogeno-verde/',
#   'summary': '<a href="https://noticiasyprotagonistas.com/actualidad/gustavo-menna-debemos-darle-un-marco-legal-a-la-produccion-de-hidrogeno-verde/" target="_blank">Gustavo Menna: «Debemos darle un marco legal a la producción de hidrógeno verde» – Noticias y Protagonistas</a>&nbsp;&nbsp;<font color="#6f6f6f">Noticias y Protagonistas</font>',
#   'score': 0.03867278998182459},
#  {'title': 'Tendencia: el hidrógeno “verde”, una salvación... Al menos para África - Diario El Dia',
#   'link': 'https://www.eldia.com/nota/2022-10-9-9-4-9-tendencia-el-hidrogeno-verde-una-salvacion-al-menos-para-africa-toda-la-semana',
#   'summary': '<a href="https://www.eldia.com/nota/2022-10-9-9-4-9-tendencia-el-hidrogeno-verde-una-salvacion-al-menos-para-africa-toda-la-semana" target="_blank">Tendencia: el hidrógeno “verde”, una salvación... Al menos para África</a>&nbsp;&nbsp;<font color="#6f6f6f">Diario El Dia</font>',
#   'score': 0.037899334182188105},
#  {'title': 'Hidrógeno verde y tren a Mendoza: las dos "patriadas" del intendente de General Alvear - - Mendoza Today',
#   'link': 'https://mendozatoday.com.ar/2022/10/04/hidrogeno-verde-y-tren-a-mendoza-las-promisorias-gestiones-de-marcolini-en-buenos-aires/',
#   'summary': '<a href="https://mendozatoday.com.ar/2022/10/04/hidrogeno-verde-y-tren-a-mendoza-las-promisorias-gestiones-de-marcolini-en-buenos-aires/" target="_blank">Hidrógeno verde y tren a Mendoza: las dos "patriadas" del intendente de General Alvear</a>&nbsp;&nbsp;<font color="#6f6f6f">- Mendoza Today</font>',
#   'score': 0.037899334182188105},
#  {'title': 'Zona Franca de Vigo expone en BNEW sus proyectos más innovadores de hidrógeno verde y semiconductores - Economía en Galicia',
#   'link': 'https://www.economiaengalicia.com/articulo/eventos/zona-franca-vigo-expone-bnew-proyectos-mas-innovadores-hidrogeno-verde-semiconductores/20221006134558021895.html',
#   'score': 0.031582778485156754},
#  {'title': 'Hidrógeno: el futuro de la Patagonia - LM Neuquen',
#   'link': 'https://mase.lmneuquen.com/hidrogeno/hidrogeno-el-futuro-la-patagonia-n954461',
#   'summary': '<a href="https://mase.lmneuquen.com/hidrogeno/hidrogeno-el-futuro-la-patagonia-n954461" target="_blank">Hidrógeno: el futuro de la Patagonia</a>&nbsp;&nbsp;<font color="#6f6f6f">LM Neuquen</font>',
#   'score': 0.024786235298274263},
#  {'title': 'La carrera del hidrógeno: Aragón capta dos de los siete proyectos que financia Bruselas - El Periódico de Aragón',
#   'link': 'https://www.elperiodicodearagon.com/aragon/2022/10/04/aragon-captar-proyectos-hidrogeno-verde-financia-europa-dos-76744951.html',
#   'summary': '<a href="https://www.elperiodicodearagon.com/aragon/2022/10/04/aragon-captar-proyectos-hidrogeno-verde-financia-europa-dos-76744951.html" target="_blank">La carrera del hidrógeno: Aragón capta dos de los siete proyectos que financia Bruselas</a>&nbsp;&nbsp;<font color="#6f6f6f">El Periódico de Aragón</font>',
#   'score': 0.024732038049040027},
#  {'title': 'Presupuestos 2023: el Gobierno insiste en su apuesta por el hidrógeno verde y las baterías - El Mundo',
#   'link': 'https://www.elmundo.es/economia/macroeconomia/2022/10/06/633ed899e4d4d839628b45e9.html',
#   'summary': '<a href="https://www.elmundo.es/economia/macroeconomia/2022/10/06/633ed899e4d4d839628b45e9.html" target="_blank">Presupuestos 2023: el Gobierno insiste en su apuesta por el hidrógeno verde y las baterías</a>&nbsp;&nbsp;<font color="#6f6f6f">El Mundo</font>',
#   'score': 0.023109350111090308},
#  {'title': 'ENGIE y el Grupo Enaex viabilizarán la prime... - BNamericas',
#   'link': 'https://www.bnamericas.com/es/noticias/engie-y-el-grupo-enaex-viabilizaran-la-primera-produccion-de-hidrogeno-verde-en-el-peru',
#   'summary': '<a href="https://www.bnamericas.com/es/noticias/engie-y-el-grupo-enaex-viabilizaran-la-primera-produccion-de-hidrogeno-verde-en-el-peru" target="_blank">ENGIE y el Grupo Enaex viabilizarán la prime...</a>&nbsp;&nbsp;<font color="#6f6f6f">BNamericas</font>',
#   'score': 0.022034496617551223},
#  {'title': 'Calderas de hidrógeno - Organización de Consumidores y Usuarios',
#   'link': 'https://www.ocu.org/vivienda-y-energia/calefaccion/consejos/calderas-hidrogeno',
#   'summary': '<a href="https://www.ocu.org/vivienda-y-energia/calefaccion/consejos/calderas-hidrogeno" target="_blank">Calderas de hidrógeno</a>&nbsp;&nbsp;<font color="#6f6f6f">Organización de Consumidores y Usuarios</font>',
#   'score': 0.016524156865516174},
#  {'title': 'El potencial del hidrógeno limpio en Latinoa... - BNamericas',
#   'link': 'https://www.bnamericas.com/es/noticias/el-potencial-del-hidrogeno-limpio-en-latinoamerica',
#   'summary': '<a href="https://www.bnamericas.com/es/noticias/el-potencial-del-hidrogeno-limpio-en-latinoamerica" target="_blank">El potencial del hidrógeno limpio en Latinoa...</a>&nbsp;&nbsp;<font color="#6f6f6f">BNamericas</font>',
#   'score': 0.01555214763813287},
#  {'title': 'Hidrógeno - Chile contará con una plataforma de libre acceso para la evaluación de producción de hidrógeno solar - Energías Renovables, el periodismo de las energías limpias. - Energías Renovables',
#   'link': 'https://www.energias-renovables.com/hidrogeno/fraunhofer-chile-creara-una-plataforma-de-libre-20221004',
#   'summary': '<a href="https://www.energias-renovables.com/hidrogeno/fraunhofer-chile-creara-una-plataforma-de-libre-20221004" target="_blank">Hidrógeno - Chile contará con una plataforma de libre acceso para la evaluación de producción de hidrógeno solar - Energías Renovables, el periodismo de las energías limpias.</a>&nbsp;&nbsp;<font color="#6f6f6f">Energías Renovables</font>',
#   'score': 0.014688139436014377},
#  {'title': 'En Cartagena se conforma un hub de hidrógeno - EL HERALDO',
#   'link': 'https://www.elheraldo.co/economia/en-cartagena-se-conforma-un-hub-de-hidrogeno-945015',
#   'summary': '<a href="https://www.elheraldo.co/economia/en-cartagena-se-conforma-un-hub-de-hidrogeno-945015" target="_blank">En Cartagena se conforma un hub de hidrógeno</a>&nbsp;&nbsp;<font color="#6f6f6f">EL HERALDO</font>',
#   'score': 0.014291162694500476},
#  {'title': '«Canarias es la candidata ideal para proyectos de hidrógeno» - El Día',
#   'link': 'https://www.eldia.es/economia/2022/10/08/canarias-candidata-ideal-proyectos-hidrogeno-76994875.html',
#   'summary': '<a href="https://www.eldia.es/economia/2022/10/08/canarias-candidata-ideal-proyectos-hidrogeno-76994875.html" target="_blank">«Canarias es la candidata ideal para proyectos de hidrógeno»</a>&nbsp;&nbsp;<font color="#6f6f6f">El Día</font>',
#   'score': 0.013558282556320963},
#  {'title': 'Toyota muestra las ventajas de las carretillas de hidrógeno - Noticias de Transporte',
#   'link': 'https://www.nexotrans.com/noticia/107074/nexolog/toyota-muestra-las-ventajas-de-las-carretillas-de-hidrogeno.html',
#   'summary': '<a href="https://www.nexotrans.com/noticia/107074/nexolog/toyota-muestra-las-ventajas-de-las-carretillas-de-hidrogeno.html" target="_blank">Toyota muestra las ventajas de las carretillas de hidrógeno</a>&nbsp;&nbsp;<font color="#6f6f6f">Noticias de Transporte</font>',
#   'score': 0.012589833802298037},
#  {'title': 'Inyecciones de hidrógeno: la solución para no matar a los coches diésel - ADSLZone',
#   'link': 'https://www.adslzone.net/e-movilidad/noticias-en-marcha/inyecciones-hidrogeno-solucion-no-matar-coches-diesel/',
#   'summary': '<a href="https://www.adslzone.net/e-movilidad/noticias-en-marcha/inyecciones-hidrogeno-solucion-no-matar-coches-diesel/" target="_blank">Inyecciones de hidrógeno: la solución para no matar a los coches diésel</a>&nbsp;&nbsp;<font color="#6f6f6f">ADSLZone</font>',
#   'score': 0.012589833802298037},
#  {'title': 'Así es el nuevo sistema que adapta los motores diésel para que funcionen con hidrógeno - Motor.es',
#   'link': 'https://www.motor.es/futuro/sistema-adapta-motores-diesel-funcionen-hidrogeno-202290321.html',
#   'summary': '<a href="https://www.motor.es/futuro/sistema-adapta-motores-diesel-funcionen-hidrogeno-202290321.html" target="_blank">Así es el nuevo sistema que adapta los motores diésel para que funcionen con hidrógeno</a>&nbsp;&nbsp;<font color="#6f6f6f">Motor.es</font>',
#   'score': 0.012297046969686455},
#  {'title': 'El puerto de Long Beach se une a la alianza del hidrógeno limpio - World Energy Trade - worldenergytrade',
#   'link': 'https://www.worldenergytrade.com/logistica/puertos-y-aduanas/puerto-long-beach-alianza-hidrogeno-limpio',
#   'summary': '<a href="https://www.worldenergytrade.com/logistica/puertos-y-aduanas/puerto-long-beach-alianza-hidrogeno-limpio" target="_blank">El puerto de Long Beach se une a la alianza del hidrógeno limpio - World Energy Trade</a>&nbsp;&nbsp;<font color="#6f6f6f">worldenergytrade</font>',
#   'score': 0.012017568629466308},
#  {'title': 'Recargas cada 60 kms y más hidrógeno: la Eurocámara acelera el coche eléctrico - lainformacion.com',
#   'link': 'https://www.lainformacion.com/economia-negocios-y-finanzas/puntos-recarga-electricos-hidrogeno-eurocamara-coche-electrico/2874546/',
#   'summary': '<a href="https://www.lainformacion.com/economia-negocios-y-finanzas/puntos-recarga-electricos-hidrogeno-eurocamara-coche-electrico/2874546/" target="_blank">Recargas cada 60 kms y más hidrógeno: la Eurocámara acelera el coche eléctrico</a>&nbsp;&nbsp;<font color="#6f6f6f">lainformacion.com</font>',
#   'score': 0.012017568629466308},
#  {'title': 'El papel del hidrógeno en la transición energética genera dudas en Catalunya por su baja eficiencia - Público',
#   'link': 'https://www.publico.es/sociedad/papel-hidrogeno-transicion-energetica-genera-dudas-catalunya-baja-eficiencia.html',
#   'summary': '<a href="https://www.publico.es/sociedad/papel-hidrogeno-transicion-energetica-genera-dudas-catalunya-baja-eficiencia.html" target="_blank">El papel del hidrógeno en la transición energética genera dudas en Catalunya por su baja eficiencia</a>&nbsp;&nbsp;<font color="#6f6f6f">Público</font>',
#   'score': 0.011750511548811501},
#  {'title': 'Alianza de Reganosa con dos gigantes energéticos para exportar hidrógeno - La Voz de Galicia',
#   'link': 'https://www.lavozdegalicia.es/noticia/economia/2022/10/04/alianza-reganosa-dos-gigantes-energeticos-exportar-hidrogeno/0003_202210G4P30991.htm',
#   'summary': '<a href="https://www.lavozdegalicia.es/noticia/economia/2022/10/04/alianza-reganosa-dos-gigantes-energeticos-exportar-hidrogeno/0003_202210G4P30991.htm" target="_blank">Alianza de Reganosa con dos gigantes energéticos para exportar hidrógeno</a>&nbsp;&nbsp;<font color="#6f6f6f">La Voz de Galicia</font>',
#   'score': 0.011750511548811501},
#  {'title': 'Gaussin y Lhyfe desarrollarán movilidad con hidrógeno en puertos, aeropuertos y centros logísticos - Movilidad sostenible - Ecomotion - Energética XXI',
#   'link': 'https://energetica21.com/noticia/gaussin-y-lhyfe-desarrollaran-movilidad-con-hidrogeno-en-puertos-aeropuertos-y-centros-logisticos',
#   'summary': '<a href="https://energetica21.com/noticia/gaussin-y-lhyfe-desarrollaran-movilidad-con-hidrogeno-en-puertos-aeropuertos-y-centros-logisticos" target="_blank">Gaussin y Lhyfe desarrollarán movilidad con hidrógeno en puertos, aeropuertos y centros logísticos - Movilidad sostenible - Ecomotion</a>&nbsp;&nbsp;<font color="#6f6f6f">Energética XXI</font>',
#   'score': 0
a>&nbsp;&nbsp;<font color="#6f6f6f">Energética XXI</font>',
#   'score': 0.0},
#  {'title': 'Sierra Grande se prepara para ser el polo energético de Río Negro - Diario Río Negro',
#   'link': 'https://www.rionegro.com.ar/energia/sierra-grande-se-prepara-para-ser-el-polo-energetico-de-rio-negro-2534184/',
#   'summary': '<a href="https://www.rionegro.com.ar/energia/sierra-grande-se-prepara-para-ser-el-polo-energetico-de-rio-negro-2534184/" target="_blank">Sierra Grande se prepara para ser el polo energético de Río Negro</a>&nbsp;&nbsp;<font color="#6f6f6f">Diario Río Negro</font>',
#   'score': 0.0},
#  {'title': 'Macron dice sobre el MidCat que "es Francia la que hoy exporta gas a España" - El Periodico de la Energía',
#   'link': 'https://elperiodicodelaenergia.com/macron-midcat-francia-hoy-exporta-gas-espana/',
#   'summary': '<a href="https://elperiodicodelaenergia.com/macron-midcat-francia-hoy-exporta-gas-espana/" target="_blank">Macron dice sobre el MidCat que "es Francia la que hoy exporta gas a España"</a>&nbsp;&nbsp;<font color="#6f6f6f">El Periodico de la Energía</font>',
#   'score': 0.0},
#  {'title': 'Expertos analizan en la UAL los retos regulatorios de los gases renovables - Almeria Noticias',
#   'link': 'https://www.almerianoticias.es/expertos-analizan-en-la-ual-los-retos-regulatorios-de-los-gases-renovables/',
#   'summary': '<a href="https://www.almerianoticias.es/expertos-analizan-en-la-ual-los-retos-regulatorios-de-los-gases-renovables/" target="_blank">Expertos analizan en la UAL los retos regulatorios de los gases renovables</a>&nbsp;&nbsp;<font color="#6f6f6f">Almeria Noticias</font>',
#   'score': 0.0},
#  {'title': 'Mabel Herrera: “Afianzarnos para la etapa semiindustrial” - Tiempo Sur',
#   'link': 'https://www.tiemposur.com.ar/politica/mabel-herrera-afianzarnos-para-la-etapa-semiindustrial',
#   'summary': '<a href="https://www.tiemposur.com.ar/politica/mabel-herrera-afianzarnos-para-la-etapa-semiindustrial" target="_blank">Mabel Herrera: “Afianzarnos para la etapa semiindustrial”</a>&nbsp;&nbsp;<font color="#6f6f6f">Tiempo Sur</font>',
#   'score': 0.0},
#  {'title': 'La Ruta Valenciana del Biogás: una ambición realista - El Periodico de la Energía',
#   'link': 'https://elperiodicodelaenergia.com/la-ruta-valenciana-del-biogas-una-ambicion-realista/',
#   'summary': '<a href="https://elperiodicodelaenergia.com/la-ruta-valenciana-del-biogas-una-ambicion-realista/" target="_blank">La Ruta Valenciana del Biogás: una ambición realista</a>&nbsp;&nbsp;<font color="#6f6f6f">El Periodico de la Energía</font>',
#   'score': 0.0},
#  {'title': 'Alemania y Holanda apuestan por la seguridad energética y la neutralidad climática - El Periodico de la Energía',
#   'link': 'https://elperiodicodelaenergia.com/alemania-holanda-apuestan-seguridad-energetica-neutralidad-climatica/',
#   'summary': '<a href="https://elperiodicodelaenergia.com/alemania-holanda-apuestan-seguridad-energetica-neutralidad-climatica/" target="_blank">Alemania y Holanda apuestan por la seguridad energética y la neutralidad climática</a>&nbsp;&nbsp;<font color="#6f6f6f">El Periodico de la Energía</font>',
#   'score': 0.0},
#  {'title': 'Llega a Berlín el primer cargador eléctrico con triple conectividad a placas solares, Alexa y dispositivos inteligentes - Movilidad sostenible - Ecomotion - Energética XXI',
#   'link': 'https://www.energetica21.com/noticia/llega-a-berlin-el-primer-cargador-electrico-con-triple-conectividad-a-placas-solares-alexa-y-dispositivos-inteligentes',
#   'summary': '<a href="https://www.energetica21.com/noticia/llega-a-berlin-el-primer-cargador-electrico-con-triple-conectividad-a-placas-solares-alexa-y-dispositivos-inteligentes" target="_blank">Llega a Berlín el primer cargador eléctrico con triple conectividad a placas solares, Alexa y dispositivos inteligentes - Movilidad sostenible - Ecomotion</a>&nbsp;&nbsp;<font color="#6f6f6f">Energética XXI</font>',
#   'score': 0
a>&nbsp;&nbsp;<font color="#6f6f6f">Energética XXI</font>',
#   'score': 0.0},
#  {'title': 'BayWa r.e. y BT Group firman un PPA Virtual para un parque eólico terrestre en Escocia - Eólica - Energética XXI',
#   'link': 'https://www.energetica21.com/noticia/baywa-re-y-bt-group-firman-un-ppa-virtual-para-un-parque-eolico-terrestre-en-escocia-',
#   'summary': '<a href="https://www.energetica21.com/noticia/baywa-re-y-bt-group-firman-un-ppa-virtual-para-un-parque-eolico-terrestre-en-escocia-" target="_blank">BayWa r.e. y BT Group firman un PPA Virtual para un parque eólico terrestre en Escocia - Eólica</a>&nbsp;&nbsp;<font color="#6f6f6f">Energética XXI</font>',
#   'score': 0.0},
#  {'title': 'La aceleración del incremento eólico en el mix energético español es indispensable ante la coyuntura actual - Eólica - Energética XXI',
#   'link': 'https://energetica21.com/noticia/la-aceleracion-del-incremento-eolico-en-el-mix-energetico-espanol-es-indispensable-ante-la-coyuntura-actual',
#   'summary': '<a href="https://energetica21.com/noticia/la-aceleracion-del-incremento-eolico-en-el-mix-energetico-espanol-es-indispensable-ante-la-coyuntura-actual" target="_blank">La aceleración del incremento eólico en el mix energético español es indispensable ante la coyuntura actual - Eólica</a>&nbsp;&nbsp;<font color="#6f6f6f">Energética XXI</font>',
#   'score': 0.0},
#  {'title': 'Grupo Noria presentará sus novedades en eficiencia energética y sostenibilidad en Efintec - Eficiencia energética - Energética XXI',
#   'link': 'https://www.energetica21.com/noticia/grupo-noria-presentara-sus-novedades-en-eficiencia-energetica-y-sostenibilidad-en-efintec-',
#   'summary': '<a href="https://www.energetica21.com/noticia/grupo-noria-presentara-sus-novedades-en-eficiencia-energetica-y-sostenibilidad-en-efintec-" target="_blank">Grupo Noria presentará sus novedades en eficiencia energética y sostenibilidad en Efintec - Eficiencia energética</a>&nbsp;&nbsp;<font color="#6f6f6f">Energética XXI</font>',
#   'score': 0.0}]

# %%
bag_of_words = []
for i in range(len(results)):
  bag_of_words.append(string_treatment(results[i]['summary']))

unique_words = set(bag_of_words[0])

for i in range(len(results)):
  if i == 0:
    continue

  unique_words = unique_words.union(bag_of_words[i])

# %%
unique_words
# Out:
# {'',
#  '0',
#  '00031664984409461433521',
#  '0003_202210g4p30991',
#  '0004',
#  '04',
#  '05',
#  '06',
#  '07',
#  '08',
#  '1',
#  '10',
#  '104',
#  '1045',
#  '107074',
#  '1087091',
#  '11',
#  '11981644',
#  '11981685',
#  '122',
#  '13',
#  '134',
#  '134132923',
#  '13474',
#  '142883',
#  '165gw',
#  '180',
#  '2',
#  '200',
#  '2000',
#  '2022',
#  '20221004',
#  '20221006134558021895',
#  '20221006162336',
#  '20221007',
#  '202210070333432264809',
#  '20221010',
#  '20221095047',
#  '202290321',
#  '2023',
#  '2025',
#  '2025_111665143857',
#  '2030',
#  '20minutos',
#  '22',
#  '2302031',
#  '2302059',
#  '250',
#  '2534184',
#  '2535379',
#  '2874546',
#  '2874723',
#  '2874747',
#  '30',
#  '370859',
#  '4',
#  '5',
#  '50',
#  '5063793',
#  '60',
#  '606',
#  '633ed899e4d4d839628b45e9',
#  '65gw',
#  '6f6f6f',
#  '709679031_0',
#  '76744951',
#  '76994875',
#  '83',
#  '8561908',
#  '9',
#  '9012247',
#  '944235',
#  '945015',
#  '_blank',
#  'a',
#  'abc',
#  'abo',
#  'abono',
#  'acceso',
#  'acelera',
#  'aceleracion',
#  'actual',
#  'actualidad',
#  'acuerda',
#  'acuerdan',
#  'acuerdos',
#  'adapta',
#  'adslzone',
#  'aduanas',
#  'aeh2',
#  'aeropuertos',
#  'africa',
#  'agencia',
#  'aire',
#  'aires',
#  'al',
#  'alcalde',
#  'alemania',
#  'alexa',
#  'alianza',
#  'almeria',
#  'almerianoticias',
#  'alternativas',
#  'alvear',
#  'ambicion',
#  'ambiciosos',
#  'ambiental',
#  'ambito',
#  'amoniaco',
#  'amplian',
#  'ampliar',
#  'analizan',
#  'aniversario',
#  'ansasol',
#  'ante',
#  'anuales',
#  'apostar',
#  'apoyar',
#  'aprueba',
#  'aps',
#  'apuesta',
#  'apuestan',
#  'apunta',
#  'ar',
#  'aragon',
#  'argentina',
#  'articulo',
#  'asi',
#  'aspecto',
#  'aspira',
#  'astilleros',
#  'asturias',
#  'atrae',
#  'audio',
#  'augura',
#  'aumentar',
#  'australia',
#  'autoconsumo',
#  'autonomia',
#  'avanzados',
#  'ayudara',
#  'azul',
#  'b1o',
#  'baja',
#  'banco',
#  'bariloche',
#  'bariloche2000',
#  'barranquilla',
#  'barrios',
#  'basf',
#  'baterias',
#  'baywa',
#  'bci',
#  'beach',
#  'berlin',
#  'bierzo',
#  'bilbao',
#  'biobiochile',
#  'biocombustibles',
#  'biogas',
#  'bloqueo',
#  'bluefloat',
#  'bnamericas',
#  'bnew',
#  'boric',
#  'bp',
#  'brey',
#  'bruselas',
#  'bt',
#  'buenos',
#  'buscan',
#  'c2',
#  'c3',
#  'cada',
#  'cadiz',
#  'calderas',
#  'calefaccion',
#  'cambio',
#  'cambiocolombia',
#  'canarias',
#  'candidata',
#  'capta',
#  'captar',
#  'caracol',
#  'cargador',
#  'carrera',
#  'carreras',
#  'carretillas',
#  'cartagena',
#  'casi',
#  'castellon',
#  'castilla',
#  'catalunya',
#  'ccaa',
#  'celebra',
#  'centro',
#  'centros',
#  'cepsa',
#  'chapuzas',
#  'chile',
#  'chilena',
#  'chips',
#  'ciencia',
#  'ciuden',
#  'cl',
#  'clave',
#  'climatica',
#  'co',
#  'coast',
#  'coche',
#  'coches',
#  'colectivo',
#  'colombia',
#  'color',
#  'colorada',
#  'colores',
#  'com',
#  'comercio',
#  'comision',
#  'commodities',
#  'como',
#  'comunidad',
#  'comunitat',
#  'con',
#  'concientizando',
#  'concretarse',
#  'conectividad',
#  'conforma',
#  'consejos',
#  'consolidarse',
#  'consumidores',
#  'consumo',
#  'contara',
#  'continental',
#  'continua',
#  'continuan',
#  'convertira',
#  'convocara',
#  'cooperacion',
#  'corea',
#  'coyuntura',
#  'crear',
#  'creara',
#  'crecimiento',
#  'crisis',
#  'cuales',
#  'cuenca',
#  'cuestiona',
#  'culmina',
#  'cummins',
#  'darle',
#  'de',
#  'debemos',
#  'del',
#  'desarrollar',
#  'desarrollaran',
#  'desarrollo',
#  'descarbonizacion',
#  'destinara',
#  'df',
#  'dfsud',
#  'dia',
#  'diario',
#  'diariodeleon',
#  'diariodetransporte',
#  'dice',
#  'diesel',
#  'digital',
#  'digitos',
#  'directivos',
#  'directivosyempresas',
#  'dispositivos',
#  'dobles',
#  'dos',
#  'dudas',
#  'e',
#  'ecomotion',
#  'economia',
#  'economiadigital',
#  'economiaengalicia',
#  'economista',
#  'edp',
#  'educando',
#  'efe',
#  'eficiencia',
#  'el',
#  'elchapuzasinformatico',
#  'elcomercio',
#  'eldia',
#  'eldigitalcastillalamancha',
#  'eleconomista',
#  'electrico',
#  'electricos',
#  'electrolizadores',
#  'elespanol',
#  'elheraldo',
#  'elige',
#  'elmercantil',
#  'elmundo',
#  'elobservador',
#  'elperiodicodearagon',
#  'elperiodicodelaenergia',
#  'elpinguino',
#  'elsaltodiario',
#  'elsoldemexico',
#  'eltiempo',
#  'emotivo',
#  'empleos',
#  'empresas',
#  'en',
#  'enaex',
#  'encuentra',
#  'enel',
#  'energetica',
#  'energetica21',
#  'energetico',
#  'energeticos',
#  'energia',
#  'energiaestrategica',
#  'energiahoy',
#  'energias',
#  'energy',
#  'enerxia',
#  'engie',
#  'eolica',
#  'eolico',
#  'es',
#  'escocia',
#  'escuela',
#  'espana',
#  'espanol',
#  'espanolas',
#  'esplendor',
#  'esta',
#  'estara',
#  'estate',
#  'este',
#  'estrategica',
#  'estrategico',
#  'eurocamara',
#  'europa',
#  'europea',
#  'europeo',
#  'europeos',
#  'euros',
#  'evaluacion',
#  'eventos',
#  'evitar',
#  'exigen',
#  'exigencias',
#  'exito',
#  'experimental',
#  'expertos',
#  'explosion',
#  'expone',
#  'exporta',
#  'exportar',
#  'fabrica',
#  'fabrican',
#  'fabricante',
#  'fase',
#  'finance',
#  'financia',
#  'financiacion',
#  'finanzas',
#  'firman',
#  'firmas',
#  'flotante',
#  'fondos',
#  'font',
#  'foro',
#  'fortescue',
#  'fortia',
#  'fosil',
#  'franca',
#  'francia',
#  'fraunhofer',
#  'fuel',
#  'funcionamiento',
#  'funcionen',
#  'fundadores',
#  'fusion',
#  'futuro',
#  'galicia',
#  'gas',
#  'gaseoso',
#  'gases',
#  'gaussin',
#  'genera',
#  'generacion',
#  'general',
#  'generation',
#  'gestiones',
#  'gigantes',
#  'globales',
#  'gnl',
#  'gobierno',
#  'gran',
#  'grande',
#  'grandes',
#  'gris',
#  'group',
#  'guadalajara',
#  'guinos',
#  'gustavo',
#  'gw',
#  'h2sarea',
#  'habla',
#  'hacen',
#  'hacia',
#  'haro',
#  'harodigital',
#  'heraldo',
#  'hidrogeno',
#  'hoja',
#  'holanda',
#  'homenaje',
#  'hoy',
#  'href',
#  'htm',
#  'html',
#  'https',
#  'hub',
#  'hunter',
#  'ideal',
#  'ilo',
#  'inaugura',
#  'incentivar',
#  'incerteza',
#  'incluidos',
#  'incorporar',
#  'incrementar',
#  'incremento',
#  'indispensable',
#  'industria',
#  'industriales',
#  'infobae',
#  'informatico',
#  'ingenieros',
#  'ingeteam',
#  'inhouse',
#  'inicio',
#  'innovacion',
#  'innovadores',
#  'insiste',
#  'instalacion',
#  'instan',
#  'inteligentes',
#  'intendente',
#  'interesada',
#  'inversion',
#  'invertira',
#  'investing',
#  'inyecciones',
#  'iprofesional',
#  'ips',
#  'ipsnoticias',
#  'javier',
#  'jerez',
#  'jujuy',
#  'jujuyaldia',
#  'junta',
#  'juridica',
#  'keme',
#  'kms',
#  'la',
#  'laboratorio',
#  'lainformacion',
#  'las',
#  'latinoa',
#  'latinoamerica',
#  'lavanguardia',
#  'lavozdegalicia',
#  'leer',
#  'legal',
#  'leon',
#  'ley',
#  'lhyfe',
#  'liberal',
#  'liberaldecastilla',
#  'libre',
#  'licitaciones',
#  'limpias',
#  'limpio',
#  'listo',
#  'llame',
#  'llamelo',
#  'llega',
#  'lmneuquen',
#  'lo',
#  'local',
#  'logistica',
#  'logisticos',
#  'long',
#  'los',
#  'lu17',
#  'lugo',
#  'm',
#  'macroeconomia',
#  'macron',
#  'magallanes',
#  'magallanicas',
#  'magazine',
#  'manager',
#  'mancha',
#  'mano',
#  'mantiene',
#  'mapa',
#  'marcha',
#  'marco',
#  'marcolini',
#  'maritimo',
#  'mas',
#  'mase',
#  'matar',
#  'mayor',
#  'mde',
#  'me',
#  'mediante',
#  'medioambiente',
#  'mejor',
#  'mendoza',
#  'mendozatoday',
#  'menna',
#  'menos',
#  'mercado',
#  'mercantil',
#  'mes',
#  'mexico',
#  'midcat',
#  'mil',
#  'millonaria',
#  'millones',
#  'misiones',
#  'mix',
#  'monte',
#  'montero',
#  'motor',
#  'motoreco',
#  'motores',
#  'movilidad',
#  'muestra',
#  'mundo',
#  'mw',
#  'mx',
#  'n5551298',
#  'n954461',
#  'n954510',
#  'nacional',
#  'nbsp',
#  'ned',
#  'negocio',
#  'negocios',
#  'negro',
#  'net',
#  'neton',
#  'neutralidad',
#  'news',
#  'nexolog',
#  'nexotrans',
#  'next',
#  'nextgen',
#  'niponas',
#  'no',
#  'nortegas',
#  'norvento',
#  'nota',
#  'noticia',
#  'noticia_180105',
#  'noticias',
#  'noticiasyprotagonistas',
#  'nt',
#  'nuevo',
#  'nuevos',
#  'objetivos',
#  'observador',
#  'octubre',
#  'ocu',
#  'ofrecer',
#  'ofreceran',
#  'opinion',
#  'oposicion',
#  'org',
#  'organizacion',
#  'otros',
#  'pacificacion',
#  'pagados',
#  'pais',
#  'paises',
#  'papa',
#  'papel',
#  'para',
#  'parking',
#  'parque',
#  'parques',
#  'partida',
#  'partir',
#  'patagonia',
#  'patriadas',
#  'pe',
#  'perfiles',
#  'periodico',
#  'periodismo',
#  'pero',
#  'peru',
#  'petronor',
#  'petroquimico',
#  'pide',
#  'pidio',
#  'pierde',
#  'pinguino',
#  'placas',
#  'plan',
#  'planea',
#  'planta',
#  'plataforma',
#  'plaza',
#  'plenitude',
#  'pniec',
#  'politica',
#  'politicas',
#  'polo',
#  'pondra',
#  'pone',
#  'por',
#  'portugal',
#  'postula',
#  'potencial',
#  'power',
#  'ppa',
#  'prepara',
#  'presenta',
#  'presento',
#  'presidente',
#  'presiona',
#  'presupuestos',
#  'primer',
#  'primera',
#  'principado',
#  'principal',
#  'priorizar',
#  'produccion',
#  'produce',
#  'producir',
#  'programa',
#  'project',
#  'promisorias',
#  'protagonistas',
#  'protagoniza',
#  'provincia',
#  'proyecta',
#  'proyecto',
#  'proyectos',
#  'prueba',
#  'publica',
#  'publico',
#  'puerto',
#  'puertos',
#  'pumarejo',
#  'punta',
#  'puntos',
#  'pv',
#  'que',
#  'quiere',
#  'quieren',
#  'r',
#  'radio',
#  'radiopolar',
#  're',
#  'reacciones',
#  'realista',
#  'recarga',
#  'recargas',
#  'reclaman',
#  'red',
#  'reduce',
#  'reforzarse',
#  'reganosa',
#  'region',
#  'regular',
#  'regulatorios',
#  'renovable',
#  'renovables',
#  'repsol',
#  'responsable',
#  'retirado',
#  'retiro',
#  'retos',
#  'reuniones',
#  'ribera',
#  'rio',
#  'rionegro',
#  'roma',
#  'royon',
#  'rtpa',
#  'ruta',
#  'salto',
#  'salvacion',
#  'sancho',
#  'se',
#  'segunda',
#  'seguridad',
#  'semana',
#  'semiconductores',
#  'ser',
#  'sera',
#  'seremi',
#  'sevilla',
#  'shtml',
#  'sierra',
#  'siete',
#  'sistema',
#  'sobre',
#  'sociedad',
#  'sol',
#  'solar',
#  'solares',
#  'solo',
#  'solucion',
#  'son',
#  'sostenible',
#  'su',
#  'sud',
#  'sueno',
#  'suministre',
#  'sur',
#  'surtidores',
#  'sus',
#  'target',
#  'tarragona',
#  'tecnologia',
#  'television',
#  'tendencia',
#  'tener',
#  'terrestre',
#  'tes',
#  'tienen',
#  'toda',
#  'today',
#  'toyota',
#  'trade',
#  'transformara',
#  'transicion',
#  'transporte',
#  'tratar',
#  'tren',
#  'triple',
#  'tsmc',
#  'tvitec',
#  'ual',
#  'ue',
#  'un',
#  'una',
#  'une',
#  'uruguay',
#  'usach',
#  'uso',
#  'usuarios',
#  'utilizara',
#  'uy',
#  'valencia',
#  'valenciana',
#  'valenciaplaza',
#  'valle',
#  'vanguardia',
#  'vdm',
#  'vdmnoticias',
#  'veces',
#  'vende',
#  'vender',
#  'ventajas',
#  'verde',
#  'vez',
#  'viceministra',
#  'vigo',
#  'virtual',
#  'visito',
#  'viva',
#  'vivasevilla',
#  'vivienda',
#  'voz',
#  'whatsapp',
#  'world',
#  'worldenergytrade',
#  'www',
#  'xxi',
#  'y',
#  'ya',
#  'yahoo',
#  'zona'}

# %%
set(bag_of_words[0])
# Out:
# {'',
#  '10',
#  '11981644',
#  '22',
#  '6f6f6f',
#  '_blank',
#  'a',
#  'color',
#  'de',
#  'el',
#  'eleconomista',
#  'energia',
#  'es',
#  'font',
#  'hidrogeno',
#  'href',
#  'html',
#  'https',
#  'javier',
#  'nbsp',
#  'noticias',
#  'petroquimico',
#  'polo',
#  'repsol',
#  'sancho',
#  'target',
#  'tarragona',
#  'transformara',
#  'verde',
#  'www'}
